# %%
import numpy as np
import pandas as pd
from os import path
from PIL import Image
from wordcloud import WordCloud, STOPWORDS, ImageColorGenerator
import matplotlib.pyplot as plt

# %%
# Import dataset
airbnbDF = pd.read_csv("C:\\Users\RexPC\\Desktop\\Capstone\\TP034717\\dataset\\scraped_text_air_bnb_4.csv")

# %%
airbnbDF.head()
# Out:
#      user_id user_name                                        review_text  \
# 0  147929067    Vin Li  great location really quick replies well equip...
# 1  147929067    Vin Li  the host is very responsive and helpful the ap...
# 2  147929067    Vin Li  i am quite disappointed with the host due to t...
# 3  147929067    Vin Li  the suites near kl sentral station are well eq...
# 4  147929067    Vin Li  very suitable to do a business trip just like ...
#
#    word_count
# 0          58
# 1         102
# 2         131
# 3          75
# 4          84

# %%
text = " ".join(review for review in airbnbDF.review_text)
print ("There are {} words in the combination of all review.".format(len(text)))
# Out:
# There are 409427 words in the combination of all review.

# %%
# Create stopword list:
stopwords = set(STOPWORDS)
stopwords.update(['etc','give','go','to','the','this','not','of','really','us','one'])

# Generate a word cloud image
wordcloud = WordCloud(stopwords=stopwords, background_color="white").generate(text)

# Display the generated image:
# the matplotlib way:
plt.imshow(wordcloud, interpolation='bilinear')
plt.axis("off")
plt.show()

# %%
wordcloud.to_file("airbnb_wordCloud.png")

# %% [markdown]
# ### Load Trustpilot dataset

# %%
# Import dataset
trustpilotDF = pd.read_csv("C:\\Users\RexPC\\Desktop\\Capstone\\TP034717\\dataset\\scraped_text_trust_pilot_4.csv")

# %%
trustpilotDF.head()
# Out:
#                     user_id                 review_id        user_name  \
# 0  5e859137a9c3cb85b6f71b4f  5e8591403c93ae06dc6ea0d1      ahmed nabil
# 1  5a5b79110000ff000b00d142  5e85774c3c93ae0314584c10        annabelle
# 2  5e854c843d06210c4775c770  5e854ca03c93ae06dc6e8ec4            yoshi
# 3  5e85376f8a0cd74c20732c28  5e853a463c93ae06dc6e8bb6      randy smith
# 4  5e85320c8a0cd7720a732af4  5e8532683c93ae031458400d  trisha campbell
#
#    num_of_stars review_category  \
# 0             1             Bad
# 1             1             Bad
# 2             1             Bad
# 3             5       Excellent
# 4             5       Excellent
#
#                                          review_text  word_count
# 0  if i can give them worst experience i will do ...         923
# 1  i was supposed to go to paris march unfortunat...        1131
# 2  stayed at jay kollmansberger and robin befus c...        1085
# 3  we have had multiple problems with airbnb host...         430
# ...

# %%
text = " ".join(review for review in trustpilotDF.review_text)
print ("There are {} words in the combination of all review.".format(len(text)))
# Out:
# There are 865176 words in the combination of all review.

# %%
# Create stopword list:
stopwords = set(STOPWORDS)
stopwords.update(['etc','give','go','to','the','this','not','of','really','us','one','said','will'])

# Generate a word cloud image
wordcloud = WordCloud(stopwords=stopwords, background_color="white").generate(text)

# Display the generated image:
# the matplotlib way:
plt.imshow(wordcloud, interpolation='bilinear')
plt.axis("off")
plt.show()

# %%
wordcloud.to_file("trustpilot_wordCloud.png")
